# %%
import tensorflow as tf
import matplotlib.pyplot as plt

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=1)
    return tf.Variable(initial)

# dataset
"""
import numpy as np
xx = np.random.randint(0,1000,[1000,3])/1000.
yy = xx[:,0] * 2 + xx[:,1] * 1.4 + xx[:,2] * 3
"""
import numpy as np


xx=tf.random_uniform([1000,2])*1000-500
xx=tf.Session().run(xx)

#X,Y=np.meshgrid(xx[:,0] ,xx[:,1])
#print(np.shape([X,Y]))



#my_arr=np.array(range(1000000))
#np.reshape(my_arr,(1000,1000))
#print(my_arr.shape)

#my_arr2=np.array(range(10),range(10))
#print(my_arr2.shape)


yy = xx[:,0] * 2 + xx[:,1] * 3 + 400

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=1)
    return tf.Variable(initial)

# dataset
"""
import numpy as np
xx = np.random.randint(0,1000,[1000,3])/1000.
yy = xx[:,0] * 2 + xx[:,1] * 1.4 + xx[:,2] * 3
"""
import numpy as np


xx=tf.random_uniform([1000,2])*1000-500
xx=tf.Session().run(xx)

yy = xx[:,0] * 2 + xx[:,1] * 3 + 2

"""
#all 2d array
ARR=np.array([range(1000) for x in range(1000)])
np.reshape(ARR,(1000,1000))
#print(ARR)
test_ARR = ARR[600:701,600:701]
train_ARR  = ARR[:599 | 701:,:599 | 701:]


train_ARR2  = ARR[[:3 , 8:10],[:3 , 8:10]]
print(train_ARR2)
"""


#print(ARR[4:6,4:6])


X,Y=np.meshgrid(xx[:,0] ,xx[:,1])
print(np.shape(X))

test_X=X[400:500,400:500]
print(np.shape(test_X))

#my_arr=np.array(range(1000000))
#np.reshape(my_arr,(1000,1000))
#print(my_arr.shape)

#my_arr2=np.array(range(10),range(10))
#print(my_arr2.shape)
#yy_ARR=ARR[]
# Out:
# (1000, 1000)
# (100, 100)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

X=xx[:,0]
Y=xx[:,1]
import numpy as np

X,Y = np.meshgrid(X, Y)


from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter



# Plot the surface.
surf = ax.plot_surface(xx[:,0], xx[:,1], yy, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

ax.set_zlim(-2000, 2000)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))


#Axes3D.plot_surface(xx[:,0], xx[:,1], yy)

#plt.plot([x for x in range(1000)],yy,'ro')
#plt.plot(xx[:,0],yy,'ro')



# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

xx=tf.random_uniform([1000,2])*1000-500
xx=tf.Session().run(xx)




# Make data.
#X = np.arange(-5, 5, 0.25)
#Y = np.arange(-5, 5, 0.25)
X=xx[:,0]
Y=xx[:,1]


X, Y = np.meshgrid(xx[:,0], xx[:,1])
yy = np.array(X * 2 + Y * 3 + 400)
print(np.shape(Z))
Z=yy
Z[X+Y<0.]=-1000
#Z = yy[600:,:900]


#Z =  xx[:,0] * 2 + xx[:,1] * 3 + 400
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-2000, 2000)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%d'))

# Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
# Out:
# (1000, 1000)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np

def plot_X_Y(X,Y):
    X, Y = np.meshgrid(X, Y)
    Z=np.array(X*1.8-Y*0.8)
    #Z[(X+Y<2) & (Y-X>-2) & (-X+Y<2) & (Y+X>-2)] = np.nan  
    #Z[(X+Y<2) & (Y-X>-2) & (-X+Y<2) & (Y+X>-2)] = np.nan  # the diagonal slice
    Z[(X<2) & (Y>-2) & (Y<2) & (X>-2)] = np.nan

    surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False, vmin=0.5, vmax=1)
    ax.set_zlim(-6.01, 6.01)

    ax.zaxis.set_major_locator(LinearLocator(10))
    ax.zaxis.set_major_formatter(FormatStrFormatter('%.01f'))
    
    fig.colorbar(surf, shrink=0.5, aspect=5)

    plt.show()

fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
print(X)
print('first plot')
#plot_X_Y(X,Y)


##
## NOW WITHOUT TF

"""
xx=tf.random_uniform([40,2])*10-5
xx=tf.Session().run(xx)

X = xx[:,0]
Y = xx[:,1]
"""



import numpy as np
xx = np.random.randint(low=-50, high=50, size=(40, 2))/10
#xx = np.random.randint(0,1000,[40,3])/1000.

X = xx[:,0]
Y = xx[:,1]

print('second plot')
print(X)
plot_X_Y(X,Y)

# I have no idea why this doesn't return the open window in the middle... somethin with the randomness maybe
# Out:
# [-5.   -4.75 -4.5  -4.25 -4.   -3.75 -3.5  -3.25 -3.   -2.75 -2.5  -2.25
#  -2.   -1.75 -1.5  -1.25 -1.   -0.75 -0.5  -0.25  0.    0.25  0.5   0.75
#   1.    1.25  1.5   1.75  2.    2.25  2.5   2.75  3.    3.25  3.5   3.75
#   4.    4.25  4.5   4.75]
# first plot
# second plot
# [-4.4 -0.2 -1.  -0.9 -1.8  4.4  3.3  2.2 -4.8  4.6 -1.8 -0.4 -1.6 -0.9  3.1
#   2.6  4.3 -1.4  0.6 -0.2  2.2  2.4 -0.9  1.   1.  -4.2 -3.6 -1.8 -1.2 -2.3
#  -4.6  2.1  1.5  0.4 -4.1  1.3  0.6  3.4 -4.6 -2.6]
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:494: RuntimeWarning: invalid value encountered in less
#   cbook._putmask(xa, xa < 0.0, -1)

# %%
import tensorflow as tf
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np

#####################################################################################
#####################################################################################
#################
#################
#################
#################

xx=tf.random_uniform([50,2])*10-5
xx=tf.Session().run(xx)

#yy = xx[:,0] * 2 + xx[:,1] * 3 + 400



fig = plt.figure()
ax = fig.gca(projection='3d')
X = xx[:,0]
Y = xx[:,1]
X, Y = np.meshgrid(X, Y)
#R = np.sqrt(X**2 + Y**2)
#Z = np.sin(.5*R)
Z=np.array(-X*1.5+Y*0.8)
#Z[(X+Y<2) & (Y-X>-2) & (-X+Y<2) & (Y+X>-2)] = np.nan  # the diagonal slice
#Z[(X<2) & (Y>-2) & (Y<2) & (X>-2)] = np.nan  # the diagonal slice



#Z[(X**2+Y**2)>10] = np.nan  # the diagonal slice



surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False, vmin=-1, vmax=1)
ax.set_zlim(-10.01, 10.01)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.01f'))

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

#print(X)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(.5*R)

Z[X+Y>4.] = np.nan  # the diagonal slice

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False, vmin=-1, vmax=1)
#ax.set_zlim(-1.01, 1.01)

#ax.zaxis.set_major_locator(LinearLocator(10))
#ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

#fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:494: RuntimeWarning: invalid value encountered in less
#   cbook._putmask(xa, xa < 0.0, -1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as axes3d

def peaks(x, y):
    return x*np.sin(y)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')
X, Y = np.meshgrid(np.linspace(-3, 3, 100), np.linspace(-3, 3, 100))

Z = peaks(X, Y)
Z[X+Y>3] = np.nan

surf = ax.plot_surface(X, Y, Z, alpha=0.3, cmap=plt.cm.jet,
                       vmin=np.nanmin(Z), vmax=np.nanmax(Z))
cbar = plt.colorbar(surf)

plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/colors.py:494: RuntimeWarning: invalid value encountered in less
#   cbook._putmask(xa, xa < 0.0, -1)

# %%
# model
x = tf.placeholder(tf.float32, shape=[None, 2])
y_ = tf.placeholder(tf.float32, shape=[None])
W1 = weight_variable([2, 1])
y = tf.matmul(x, W1)

# training and cost function
cost_function = tf.reduce_mean(tf.square(tf.squeeze(y) - y_))
train_function = tf.train.AdamOptimizer(1e-2).minimize(cost_function)

# create a session
sess = tf.Session()

# train
sess.run(tf.global_variables_initializer())
for i in range(10000):
    sess.run(train_function, feed_dict={x:xx, y_:yy})
    if i % 1000 == 0:
        print(sess.run(cost_function, feed_dict={x:xx, y_:yy}))
# Out:
# 17.3961
# 0.00169216
# 5.08631e-11
# 2.15271e-11
# 7.48177e-12
# 2.79454e-12
# 1.05397e-12
# 1.87366e-13
# 7.07906e-14
# 7.07906e-14
